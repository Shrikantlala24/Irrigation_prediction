# %% [markdown]
# <a href="https://www.kaggle.com/code/shrikantlala/basic-eda-irrigation-need?scriptVersionId=313339043" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

train = pd.read_csv("/kaggle/input/competitions/playground-series-s6e4/train.csv")
print(f"Train shape: {train.shape}")
train.head()
# Out:
# Train shape: (630000, 21)
#    id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0   0     Loamy     4.92          32.58            1.01
# 1   1      Clay     7.08          56.61            0.44
# 2   2      Clay     5.69          27.71            0.81
# 3   3     Sandy     5.65          13.32            1.33
# 4   4      Clay     7.96          59.14            0.38
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     3.05          15.01     50.61       725.99
# 1                     2.00          22.92     67.86       985.66
# 2                     2.83          26.97     92.22      2201.70
# 3                     0.87          13.32     61.57      1357.33
# 4                     0.96          20.22     91.11      1538.20
#
#    Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0            5.90  ...  Sugarcane            Sowing    Zaid            Drip
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Soil_Type                630000 non-null  object
#  2   Soil_pH                  630000 non-null  float64
#  3   Soil_Moisture            630000 non-null  float64
#  4   Organic_Carbon           630000 non-null  float64
#  5   Electrical_Conductivity  630000 non-null  float64
#  6   Temperature_C            630000 non-null  float64
#  7   Humidity                 630000 non-null  float64
#  8   Rainfall_mm              630000 non-null  float64
#  9   Sunlight_Hours           630000 non-null  float64
#  10  Wind_Speed_kmh           630000 non-null  float64
#  11  Crop_Type                630000 non-null  object
#  12  Crop_Growth_Stage        630000 non-null  object
# ...

# %%
cat = ['Soil_Type','Crop_Type','Crop_Growth_Stage','Season','Irrigation_Type','Water_Source','Mulching_Used','Region']
train[cat]
# Out:
#        Soil_Type  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0          Loamy  Sugarcane            Sowing    Zaid            Drip
# 1           Clay      Wheat        Vegetative  Kharif         Rainfed
# 2           Clay       Rice        Vegetative  Kharif       Sprinkler
# 3          Sandy      Wheat         Flowering  Kharif           Canal
# 4           Clay      Wheat            Sowing    Rabi           Canal
# ...          ...        ...               ...     ...             ...
# 629995      Clay       Rice            Sowing  Kharif       Sprinkler
# 629996      Clay  Sugarcane        Vegetative  Kharif            Drip
# 629997      Clay     Potato        Vegetative    Zaid           Canal
# 629998      Clay  Sugarcane        Vegetative    Zaid       Sprinkler
# 629999     Loamy      Maize           Harvest  Kharif            Drip
#
#        Water_Source Mulching_Used   Region
# 0         Rainwater            No     East
# ...

# %%
train[cat].isnull().sum()
# Out:
# Soil_Type            0
# Crop_Type            0
# Crop_Growth_Stage    0
# Season               0
# Irrigation_Type      0
# Water_Source         0
# Mulching_Used        0
# Region               0
# dtype: int64

# %%
num = ['Soil_pH','Soil_Moisture','Organic_Carbon','Electrical_Conductivity','Temperature_C','Humidity','Rainfall_mm','Sunlight_Hours','Wind_Speed_kmh']
train[num]
# Out:
#         Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0          4.92          32.58            1.01                     3.05
# 1          7.08          56.61            0.44                     2.00
# 2          5.69          27.71            0.81                     2.83
# 3          5.65          13.32            1.33                     0.87
# 4          7.96          59.14            0.38                     0.96
# ...         ...            ...             ...                      ...
# 629995     6.54          13.45            1.15                     1.86
# 629996     7.03          54.49            0.96                     2.35
# 629997     6.52          11.98            0.93                     0.38
# 629998     5.93          42.86            0.33                     3.39
# 629999     7.02          35.36            1.19                     0.46
#
#         Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh
# ...

# %%
train[num].isnull().sum()
# Out:
# Soil_pH                    0
# Soil_Moisture              0
# Organic_Carbon             0
# Electrical_Conductivity    0
# Temperature_C              0
# Humidity                   0
# Rainfall_mm                0
# Sunlight_Hours             0
# Wind_Speed_kmh             0
# dtype: int64
